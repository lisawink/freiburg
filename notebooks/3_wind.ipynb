# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
wind = pd.read_csv('/Users/lisawink/Documents/paper1/data/raw_data/Freiburg_Dach_2022-09-01_2023-09-01.csv')

# %%
wind['UTC'] = pd.to_datetime(wind['UTC'], format='%d.%m.%y %H:%M', utc=True)

# %%
wind
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 0    2022-09-01 00:00:00+00:00  01.09.22 02:00             17.53287
# 1    2022-09-01 01:00:00+00:00  01.09.22 03:00             17.34965
# 2    2022-09-01 02:00:00+00:00  01.09.22 04:00             17.51205
# 3    2022-09-01 03:00:00+00:00  01.09.22 05:00             16.04460
# 4    2022-09-01 04:00:00+00:00  01.09.22 06:00             15.40496
# ...                        ...             ...                  ...
# 8742 2023-09-01 19:00:00+00:00  01.09.23 21:00             22.80843
# 8743 2023-09-01 20:00:00+00:00  01.09.23 22:00             21.56178
# 8744 2023-09-01 21:00:00+00:00  01.09.23 23:00             20.54576
# 8745 2023-09-01 22:00:00+00:00  02.09.23 00:00             20.52107
# 8746 2023-09-01 23:00:00+00:00  02.09.23 01:00             19.92167
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 0                          71.54590          14.15823
# ...

# %%
wind[wind['UTC'] == '2023-04-13 13:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 5388 2023-04-13 13:00:00+00:00  13.04.23 15:00             6.139768
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 5388                        -9999.0          8.189784
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 5388                        3.300786                            8.9756
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 5388               256.2899                138.6209          35.3529
#
#       Niederschlag (mm)
# 5388                2.2

# %%
wind[wind['UTC'] == '2023-04-13 01:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 5376 2023-04-13 01:00:00+00:00  13.04.23 03:00             7.343301
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 5376                       76.18694          7.851471
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 5376                         8.26071                          13.74956
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 5376               197.1814                     0.0             75.0
#
#       Niederschlag (mm)
# 5376                0.0

# %%
wind[wind['UTC'] == '2023-04-20 13:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 5556 2023-04-20 13:00:00+00:00  20.04.23 15:00             9.152143
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 5556                       67.18882          7.749866
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 5556                        3.153313                           5.77508
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 5556               127.1412                440.1832             75.0
#
#       Niederschlag (mm)
# 5556                0.0

# %%
wind[wind['UTC'] == '2023-04-20 01:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 5544 2023-04-20 01:00:00+00:00  20.04.23 03:00             7.421096
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 5544                       72.88126          7.516985
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 5544                        1.910355                           3.63842
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 5544               68.79228                     0.0         65.49615
#
#       Niederschlag (mm)
# 5544                0.0

# %%
wind[wind['UTC'] == '2022-11-09 13:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 1669 2022-11-09 13:00:00+00:00  09.11.22 14:00             14.79457
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 1669                       79.28187           13.2138
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 1669                        3.097587                            5.8913
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 1669               195.7598                50.78301         15.39296
#
#       Niederschlag (mm)
# 1669                0.6

# %%
wind[wind['UTC'] == '2022-11-09 01:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 1657 2022-11-09 01:00:00+00:00  09.11.22 02:00             16.20919
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 1657                       56.93651          10.37728
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 1657                        2.723547                           4.44302
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 1657               141.8404                     0.0         67.27371
#
#       Niederschlag (mm)
# 1657                0.4

# %%
wind[wind['UTC'] == '2022-11-10 01:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 1681 2022-11-10 01:00:00+00:00  10.11.22 02:00             11.41363
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 1681                       91.09404          12.21888
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 1681                        1.819627                           3.88874
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 1681               190.4322                     0.0          56.4369
#
#       Niederschlag (mm)
# 1681                0.0

# %%
wind[wind['UTC'] == '2022-11-16 13:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 1837 2022-11-16 13:00:00+00:00  16.11.22 14:00             13.06807
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 1837                       66.77972           9.97303
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 1837                        4.535189                           7.89386
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 1837               182.5907                322.6367         62.47103
#
#       Niederschlag (mm)
# 1837                0.0

# %%
wind[wind['UTC'] == '2022-11-16 01:00:00+00:00']
# Out:
#                            UTC       Lokalzeit  Lufttemperatur (°C)  \
# 1825 2022-11-16 01:00:00+00:00  16.11.22 02:00             11.32094
#
#       Relative Luftfeuchtigkeit (%)  Dampfdruck (hPa)  \
# 1825                       90.77369          12.08735
#
#       Windgeschwindigkeit Dach (m/s)  Windgeschwindigkeit Dach (m/s).1  \
# 1825                        2.812935                           6.21314
#
#       Windrichtung Dach (°)  Globalstrahlung (W/m²)  Sichtweite (km)  \
# 1825               168.0862                     0.0         10.48315
#
#       Niederschlag (mm)
# 1825                0.8

# %%
'''
temp =  pd.read_csv('/Users/lisawink/Documents/paper1/data/gap_filled_data_ta_rh.csv')
temp['datetime_UTC']=pd.to_datetime(temp['datetime_UTC'])
temp = temp[temp['variable']=='Ta_deg_C']
temp = temp[temp['data_type'] == 'observed']
'''

# %%
year = 'year'
var = 'BuAre_sum'
radius = 50
stats_dict = pd.read_csv(f'/Users/lisawink/Documents/paper1/data/processed_data/diurnal/all_year/{year,var,radius}.csv') 
stats_dict = stats_dict.drop(columns=['Unnamed: 0','Parameter.1'])
stats_dict['Time'] = pd.to_datetime(stats_dict['Time'])

# %%
stats_dict.head(20)
# Out:
#     Parameter  Pearson Correlation  Pearson p-value  Spearman Correlation  \
# 0   BuAre_sum             0.356635         0.073714              0.166182
# 1   BuAre_sum             0.401925         0.041813              0.182253
# 2   BuAre_sum             0.369436         0.063248              0.169231
# 3   BuAre_sum             0.413148         0.035922              0.166581
# 4   BuAre_sum             0.447006         0.022052              0.286203
# 5   BuAre_sum             0.431681         0.027660              0.225376
# 6   BuAre_sum             0.303092         0.132292              0.122756
# 7   BuAre_sum             0.172484         0.399461              0.021538
# 8   BuAre_sum             0.227675         0.263313             -0.019149
# 9   BuAre_sum             0.062110         0.763096             -0.004787
# 10  BuAre_sum             0.061604         0.764975             -0.020855
# 11  BuAre_sum             0.066425         0.747148             -0.088547
# ...

# %%
merged = stats_dict.merge(wind,left_on='Time', right_on='UTC', how='left')

# %%
merged.head(10)
# Out:
#    Parameter  Pearson Correlation  Pearson p-value  Spearman Correlation  \
# 0  BuAre_sum             0.356635         0.073714              0.166182
# 1  BuAre_sum             0.401925         0.041813              0.182253
# 2  BuAre_sum             0.369436         0.063248              0.169231
# 3  BuAre_sum             0.413148         0.035922              0.166581
# 4  BuAre_sum             0.447006         0.022052              0.286203
# 5  BuAre_sum             0.431681         0.027660              0.225376
# 6  BuAre_sum             0.303092         0.132292              0.122756
# 7  BuAre_sum             0.172484         0.399461              0.021538
# 8  BuAre_sum             0.227675         0.263313             -0.019149
# 9  BuAre_sum             0.062110         0.763096             -0.004787
#
#    Spearman p-value  Mutual Information                      Time  \
# 0          0.417161            0.019799 2022-09-01 00:00:00+00:00
# ...

# %%
plt.scatter(merged['Windgeschwindigkeit Dach (m/s)'],merged['Spearman Correlation'])

# %%
plt.scatter(merged['Windgeschwindigkeit Dach (m/s)'],merged['Spearman Correlation'])

# %%
wind['UTC'].loc[0] == stats_dict['Time'].loc[0]
# Out:
# False

# %%
wind['UTC'].loc[0]
# Out:
# Timestamp('2022-01-09 00:00:00+0000', tz='UTC')

# %%
stats_dict['Time'].loc[0]
# Out:
# Timestamp('2022-09-01 00:00:00+0000', tz='UTC')
